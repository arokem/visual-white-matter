# %%
ls
# Out:
# DTI.ipynb               SUB1_b2000_1.nii.gz     dMRI-signals.ipynb
# Instructions.ipynb      SUB1_b2000_2.bvals      download-data.ipynb
# README.md               SUB1_b2000_2.bvecs      index.ipynb
# SFM.ipynb               SUB1_b2000_2.nii.gz     life.ipynb
# SUB1_b2000_1.bvals      csd_odfs.png            run_notebook.py*
# SUB1_b2000_1.bvecs      csd_peaks.png           signal-formation.ipynb

# %%
import numpy as np
import matplotlib as mpl 
import matplotlib.pyplot as plt
import dipy.core.gradients as grad
from dipy.tracking.eudx import EuDX
import dipy.reconst.csdeconv as csd
from dipy.reconst import peaks
from dipy.tracking import utils
from dipy.data import read_stanford_labels
from dipy.viz import fvtk
from dipy.viz.colormap import line_colors
import scipy.io as sio

import nibabel as nib
import time

# %matplotlib inline

# %%
# Download data (about 4GB: this might take some time...)
try: #Python 3
    import urllib.request as url
except:
    import urllib as url
import os.path as op
import os
data_url = 'https://stacks.stanford.edu/file/druid:bb060nk0241/DiffusionData_Subject1.tar.gz'
for i in range(2):
    fname = data_url.split('/')[-1]
    if not op.exists(fname):
        url.urlretrieve(data_url, data_url.split('/')[-1])
        os.system('tar -xvzf DiffusionData_Subject1.tar.gz')

# %%
data_url.split('/')[-1]
# Out:
# 'DiffusionData_Subject1.tar.gz'

# %%
ls
# Out:
# DTI.ipynb               SUB1_b2000_1.nii.gz     download-data.ipynb
# Instructions.ipynb      SUB1_b2000_2.bvals      index.ipynb
# README.md               SUB1_b2000_2.bvecs      life.ipynb
# S1                      SUB1_b2000_2.nii.gz     run_notebook.py*
# SFM.ipynb               csd_odfs.png            signal-formation.ipynb
# SUB1_b2000_1.bvals      csd_peaks.png
# SUB1_b2000_1.bvecs      dMRI-signals.ipynb

# %%
img = nib.load('S1/diffusion_raw/run01_aligned_trilin.nii.gz') 
gtab = grad.gradient_table('S1/diffusion_raw/run01_aligned_trilin.bvals', 'S1/diffusion_raw/run01_aligned_trilin.bvecs')
data = img.get_data()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-10-2ecc60bc2ef3> in <module>()
# ----> 1 img = nib.load('S1/diffusion_raw/run01_aligned_trilin.nii.gz')
#       2 gtab = grad.gradient_table('S1/diffusion_raw/run01_aligned_trilin.bvals', 'S1/diffusion_raw/run01_aligned_trilin.bvecs')
#       3 data = img.get_data()
#
# /Users/arokem/anaconda3/envs/jov/lib/python2.7/site-packages/nibabel/loadsave.pyc in load(filename, **kwargs)
#      42        Image of guessed type
#      43     '''
# ---> 44     return guessed_image_type(filename).from_filename(filename, **kwargs)
#      45
#      46
#
# /Users/arokem/anaconda3/envs/jov/lib/python2.7/site-packages/nibabel/loadsave.pyc in guessed_image_type(filename)
#      74             klass = Minc2Image if signature == b'\211HDF' else Minc1Image
#      75     elif lext == '.nii':
# ---> 76         with BinOpener(filename) as fobj:
#      77             binaryblock = fobj.read(348)
#      78         ft = which_analyze_type(binaryblock)
#
# /Users/arokem/anaconda3/envs/jov/lib/python2.7/site-packages/nibabel/openers.pyc in __init__(self, fileish, *args, **kwargs)
#      72         if 'compresslevel' in arg_names and 'compresslevel' not in kwargs:
#      73             kwargs['compresslevel'] = self.default_compresslevel
# ---> 74         self.fobj = opener(fileish, *args, **kwargs)
#      75         self._name = fileish
#      76         self.me_opened = True
#
# /Users/arokem/anaconda3/envs/jov/lib/python2.7/site-packages/nibabel/openers.pyc in _gzip_open(fileish, *args, **kwargs)
#      21     # open gzip files with faster reads on large files using larger chunks
#      22     # See https://github.com/nipy/nibabel/pull/210 for discussion
# ---> 23     gzip_file = gzip.open(fileish, *args, **kwargs)
#      24     gzip_file.max_read_chunk = GZIP_MAX_READ_CHUNK
#      25     return gzip_file
#
# /Users/arokem/anaconda3/envs/jov/lib/python2.7/gzip.pyc in open(filename, mode, compresslevel)
#      32
#      33     """
# ---> 34     return GzipFile(filename, mode, compresslevel)
#      35
#      36 class GzipFile(io.BufferedIOBase):
#
# /Users/arokem/anaconda3/envs/jov/lib/python2.7/gzip.pyc in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#      92             mode += 'b'
#      93         if fileobj is None:
# ---> 94             fileobj = self.myfileobj = __builtin__.open(filename, mode or 'rb')
#      95         if filename is None:
#      96             # Issue #13781: os.fdopen() creates a fileobj with a bogus name
#
# IOError: [Errno 20] Not a directory: 'S1/diffusion_raw/run01_aligned_trilin.nii.gz'

# %%
affine = img.get_affine()

# %%
wm_img = nib.load('S1/diffusion_dt6/1st/bin/wmMask.nii.gz')
wm_data = wm_img.get_data()

# %%
fig, ax = plt.subplots(1)
ax.matshow(np.mean(data[..., ~gtab.b0s_mask], -1)[50,:,:], cmap=mpl.cm.bone)
vol= np.ones_like(wm_data) * np.nan
vol[wm_data==1] = 1
ax.matshow(vol[50,:,:], cmap=mpl.cm.jet)

#Indexer:
white_matter = (wm_data == 1)

# %%
response, ratio = csd.auto_response(gtab, data, roi_radius=10, fa_thr=0.7)

# %%
response
# Out:
# (array([ 0.00128988,  0.00029723,  0.00029723]), 457.05818014705881)

# %%
csdmodel = csd.ConstrainedSphericalDeconvModel(gtab, response)
csdpeaks = peaks.peaks_from_model(model=csdmodel,
                                  data=data,
                                  sphere=peaks.default_sphere,
                                  relative_peak_threshold=.8,
                                  min_separation_angle=45,
                                  mask=white_matter)

# %%
seeds = utils.seeds_from_mask(white_matter, density=2)

# %%
streamline_generator = EuDX(csapeaks.peak_values, csapeaks.peak_indices,
                            odf_vertices=peaks.default_sphere.vertices,
                            a_low=.05, step_sz=.5, seeds=seeds)

# %%
affine = streamline_generator.affine
streamlines = list(streamline_generator)

# %%
len(streamlines)
# Out:
# 7451708

# %%
hdr = nib.trackvis.empty_header()
hdr['voxel_size'] = img.get_header().get_zooms()[:3]
hdr['voxel_order'] = 'LAS'
hdr['dim'] = data.shape[:3]

csd_streamlines_trk = ((sl, None, None) for sl in streamlines)

csd_sl_fname = '/Users/arokem/Desktop/csd_streamline.trk'
nib.trackvis.write(csd_sl_fname, csd_streamlines_trk, hdr, points_space='voxel')

# %%
wp_lh1_matfile = 'S1/ROIs/Waypoint/LH_VOFPlane1.mat'
wp_lh2_matfile = 'S1/ROIs/Waypoint/LH_VOFPlane2.mat'

# %%
wp_lh1_mat = sio.loadmat(wp_lh1_matfile)
wp_lh2_mat = sio.loadmat(wp_lh2_matfile)

# %%
wp_lh1 = wp_lh1_mat['roi'][0,0].item()[2]
wp_lh2 = wp_lh2_mat['roi'][0,0].item()[2]

# %%
def xform_to(arr, affine):
    inv_affine = np.linalg.inv(affine)    
    return (np.dot(arr, inv_affine[:3, :3]) + inv_affine[:3, 3]).astype(int)

# %%
wp_lh1_vol = xform_to(wp_lh1, affine) 
wp_lh2_vol = xform_to(wp_lh2, affine)

# %%
fig, ax = plt.subplots(1)
i = 30
ax.matshow(np.mean(data[..., ~gtab.b0s_mask], -1)[i,:,:], cmap=mpl.cm.bone)
vol= np.ones_like(wm_data) * np.nan
vol[wp_lh1_vol[:, 0], wp_lh1_vol[:, 1], wp_lh1_vol[:, 2]] = 1
vol[wp_lh2_vol[:, 0], wp_lh2_vol[:, 1], wp_lh2_vol[:, 2]] = 1
ax.matshow(vol[i,:,:], cmap=mpl.cm.jet)

# %%
vof_candidates = utils.target(streamlines, vol, affine=np.eye(4))
vof_candidates = list(vof_candidates)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-96-8005639a7888> in <module>()
#       1 vof_candidates = utils.target(streamlines, vol, affine=np.eye(4))
# ----> 2 vof_candidates = list(vof_candidates)
#
# /Users/arokem/usr/local/lib/python3.4/site-packages/dipy/tracking/utils.py in target(streamlines, target_mask, affine, include)
#     478             ind = _to_voxel_coordinates(sl, lin_T, offset)
#     479             i, j, k = ind.T
# --> 480             state = target_mask[i, j, k]
#     481         except IndexError:
#     482             raise ValueError("streamlines points are outside of target_mask")
#
# KeyboardInterrupt:

# %%
len(cc_streamlines)
# Out:
# 100065

# %%
import dipy.tracking.life as life
reload(life)
# Out:
# <module 'dipy.tracking.life' from '/Users/arokem/usr/local/lib/python2.7/site-packages/dipy/tracking/life.pyc'>

# %%
# %%time
FM1 = life.FiberModel(gtab)
# Out:
# CPU times: user 12 µs, sys: 3 µs, total: 15 µs
# Wall time: 18.1 µs

# %%
some_streamlines = cc_streamlines[:1000]

# %%
timing = []
sl_numbers = [10, 100, 1000, 10000, 100000]
for n in sl_numbers:
    some_streamlines = streamlines[:n]
    t1 = time.time()
    FF1 = FM1.setup(some_streamlines, np.eye(4))
    t2 = time.time()
    timing.append(t2-t1)

# %%
plt.plot(sl_numbers, timing, 'o')
plt.loglog()

# %%
timing
# Out:
# [0.238447904586792, 2.697704792022705, 40.15247321128845, 960.568813085556]

# %%
500000/60.
# Out:
# 8333.333333333334

# %%
FF1 = FM1.

# %%
plt.plot(FF1.predict()[3])
plt.plot(FF1.data[3])

# %%
nz = FF1.beta>0

# %%
np.sum(nz)
# Out:
# 2190
